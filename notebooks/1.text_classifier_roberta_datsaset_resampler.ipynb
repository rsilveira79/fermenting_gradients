# %%
import pandas as pd
import numpy as np
import json, re
from tqdm import tqdm_notebook
import pickle

# Torch, Sklearn imports
from sklearn.model_selection import train_test_split
import torch
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader, RandomSampler

## NLP libs
from nltk import download
import gensim

import warnings
warnings.filterwarnings("ignore")

# %%
# !ls -lah
# Out:
# total 67656
# drwxr-xr-x  29 rsilvei  ADESI\Domain Users   928B Oct 28 16:09 .
# drwxr-xr-x  24 rsilvei  ADESI\Domain Users   768B Aug 21 10:43 ..
# drwxr-xr-x  18 rsilvei  ADESI\Domain Users   576B Oct 28 13:22 .ipynb_checkpoints
# -rw-r--r--   1 rsilvei  ADESI\Domain Users    30K Sep  9 17:08 1.text_classifier_roberta.ipynb
# -rw-r--r--   1 rsilvei  ADESI\Domain Users    22K Oct 28 15:19 1.text_classifier_roberta_datsaset_resampler.ipynb
# -rw-r--r--   1 rsilvei  ADESI\Domain Users    23K Aug 30 10:53 2.uncertainty_swag.ipynb
# drwxr-xr-x@ 10 rsilvei  ADESI\Domain Users   320B Aug 19 09:36 2017-06-custom-intent-engines
# -rw-r--r--   1 rsilvei  ADESI\Domain Users    28K Sep  5 11:24 3.causality_review.ipynb
# -rw-r--r--   1 rsilvei  ADESI\Domain Users   112K Sep 23 15:45 4.dpp_diversity_phrases.ipynb
# -rw-r--r--   1 rsilvei  ADESI\Domain Users   156K Sep 18 13:48 4.dpp_image.ipynb
# -rw-r--r--   1 rsilvei  ADESI\Domain Users    19K Sep 23 16:26 4.nips2019_papers.ipynb
# -rw-r--r--   1 rsilvei  ADESI\Domain Users   1.2M Sep 23 21:54 4.nips2019_papers_simple_altair.ipynb
# -rw-r--r--   1 rsilvei  ADESI\Domain Users   229K Sep 23 15:45 4.sample_dpp.ipynb
# -rw-r--r--   1 rsilvei  ADESI\Domain Users   2.3K Sep 26 14:55 5.causal_inference_resumés.ipynb
# -rw-r--r--   1 rsilvei  ADESI\Domain Users    18K Oct 11 17:20 5.dowhy_tutorial.ipynb
# -rw-r--r--   1 rsilvei  ADESI\Domain Users    17K Sep 30 17:24 5.mediation_analysis.ipynb
# -rw-r--r--   1 rsilvei  ADESI\Domain Users    49K Oct 24 17:27 6.gpytorch_uncertainty.ipynb
# -rw-r--r--   1 rsilvei  ADESI\Domain Users    32K Oct 25 12:01 6.gpytorch_uncertainty_multiclass_cifar.ipynb
# -rw-r--r--   1 rsilvei  ADESI\Domain Users    33K Oct 25 21:53 6.gpytorch_uncertainty_text_classifier.ipynb
# -rw-r--r--   1 rsilvei  ADESI\Domain Users    15K Oct 25 14:38 6.pyro_text_classification.ipynb
# drwxr-xr-x  14 rsilvei  ADESI\Domain Users   448B Sep 19 11:53 Maximal-Marginal-Relevance
# -rw-r--r--   1 rsilvei  ADESI\Domain Users    25K Oct 11 12:45 causal_model.png
# drwxr-xr-x   3 rsilvei  ADESI\Domain Users    96B Oct 25 11:56 data
# -rw-r--r--   1 rsilvei  ADESI\Domain Users   176K Oct 28 16:08 intent_186.csv
# -rw-r--r--@  1 rsilvei  ADESI\Domain Users   124K Oct 25 16:41 intents_phrases_183.pkl
# -rw-r--r--   1 rsilvei  ADESI\Domain Users   617K Aug 30 09:58 model_elmo_swag_uncertainty.pth
# -rw-r--r--   1 rsilvei  ADESI\Domain Users    10M Sep 12 12:57 nips_2018.pkl
# -rw-r--r--   1 rsilvei  ADESI\Domain Users    14M Sep 18 10:21 nips_2018_bert.pkl
# -rw-r--r--   1 rsilvei  ADESI\Domain Users   6.1M Sep 12 17:58 nips_2018_elmo.pkl

# %%
dataset = pd.read_csv('intent_186.csv')
dataset['phrase'] = dataset['TrainPhrase'].apply(lambda x: json.loads(x)['en-US'])
dataset.drop(columns = ['TrainPhrase'], inplace=True)
dataset.rename(columns = {"Intent":"intent"}, inplace = True)
dataset.tail(10)
# Out:
#                           intent                                  phrase
# 2765  workerVeteranStatus.update               Worker is in the military
# 2766  workerVeteranStatus.update                  She is in the military
# 2767  workerVeteranStatus.update          correct veteran status for her
# 2768  workerVeteranStatus.update           edit military service for him
# 2769  workerVeteranStatus.update  adjust veteran information for Vincent
# 2770  workerVeteranStatus.update         modify her military information
# 2771  workerVeteranStatus.update           modify worker military status
# 2772  workerVeteranStatus.update          change employee veteran status
# 2773  workerVeteranStatus.update              change his military status
# 2774  workerVeteranStatus.update           update Brian's veteran status

# %%
dataset.intent.value_counts()
# Out:
# positionRelationships.update                  49
# workerMaritalStatus.update                    39
# associateGovernmentRegistration.update        39
# question.detect                               37
# personMaritalStatus.update                    35
# personBirthInformation.update                 33
# workerTobaccoUsageStatus.update               32
# personGovernmentRegistration.update           30
# associateGovernmentRegistration.create        28
# workerBirthInformation.update                 28
# personTobaccoUsageStatus.update               27
# workerPersonalEmail.update                    27
# workerPersonalPhoneNumber.update              26
# associateWageGarnishmentInstruction.create    26
# workerLGBT.update                             25
# personPersonalPhoneNumber.update              24
# workerDeathDate.inform                        24
# personEthnicity.update                        24
# personLGBT.update                             23
# worker.changeOrganization                     23
# personGovernmentRegistration.create           23
# jobRequisition.create                         23
# workerEthnicity.update                        23
# workerBloodGroup.update                       23
# jobPosting.create                             22
# compensationPlan.update                       22
# workerPersonalAddress.update                  22
# personBloodGroup.update                       22
# personPersonalEmail.update                    21
# compensationPlan.create                       21
#                                               ..
# workerName.update                             10
# person.create                                 10
# level.update                                  10
# campus.update                                 10
# jobFamily.deactivate                          10
# position.update                               10
# transfer                                       9
# evaluation.review                              9
# location.create                                9
# workAssignment.create                          9
# position.delete                                9
# assessment.update                              9
# location.deactivate                            9
# location.delete                                9
# position.deactivate                            9
# location.activate                              9
# team.update                                    9
# demote                                         9
# location.update                                9
# worker.changeLevel                             8
# jobApplication.evaluate                        8
# position.activate                              8
# termination.revoke                             8
# personDeathDate.inform                         8
# helper.questions                               8
# location.read                                  7
# jobSearch.update                               6
# jobSearch.create                               6
# view.job                                       6
# jobSearch.delete                               5
# Name: intent, Length: 186, dtype: int64

# %%
with open('intents_phrases_186.pkl', 'wb') as f:
    pickle.dump(dataset,f)

# %%
with open('intents_phrases_186.pkl', 'rb') as f:
    dataset = pickle.load(f)

# %%
dataset.tail()
# Out:
#                           intent                           phrase
# 2770  workerVeteranStatus.update  modify her military information
# 2771  workerVeteranStatus.update    modify worker military status
# 2772  workerVeteranStatus.update   change employee veteran status
# 2773  workerVeteranStatus.update       change his military status
# 2774  workerVeteranStatus.update    update Brian's veteran status

# %%
#dataset_path = "intents_phrases_183.pkl"
#dataset = pd.read_pickle(dataset_path)
#dataset = dataset.rename(columns={"usersays":"phrase"})
#dataset.tail()

# %%
# ## Make shorter version of the dataset
# selected_intents = ['position.update',
#                     'jobBoard.update',
#                     'job.create',
#                     'lateralMove',
#                     'band.update',
#                     'adjustment',
#                    'worker.changeManager']
# dataset = dataset[dataset.intent.isin(selected_intents)].reset_index(drop=True)
# print(len(set(dataset.intent)))
# dataset.tail()

# %%
def resample_dataset(dataframe,
                     label_column = 'intent',
                     feature_column = 'phrase',
                     max_samples = 100):
    
    from imblearn.over_sampling import SMOTE, RandomOverSampler, ADASYN

    ## Build label vocabulary
    label_to_ix = {}
    for label in dataset[label_column]:
        for word in label.split():
            if word not in label_to_ix:
                label_to_ix[word]=len(label_to_ix)
          
    ## Define Sampling Strategy based on number of samples
    classes_sample = {}
    for cls in list(set(label_to_ix.values())):
        classes_sample.update({cls:max_samples})

    sampler = RandomOverSampler(sampling_strategy = classes_sample, random_state=42)
    x = np.array(dataset.index).reshape(-1, 1)
    y = np.array(list(dataset[label_column].apply(lambda x: label_to_ix[x])))
    
    ## Oversampling
    x_resampled, y_resampled = sampler.fit_sample(x, y)
    dataset_resampled = pd.DataFrame(columns=[feature_column,label_column])
    
    ## Iterating
    for i, item in enumerate(x_resampled):
        row = {
            feature_column :dataset[feature_column].loc[item[0]],
            label_column: list(label_to_ix.keys())[y_resampled[i]]
        }
        dataset_resampled = dataset_resampled.append(row, ignore_index=True)
    return dataset_resampled

# %%
new_dataset = resample_dataset(dataset, max_samples = 50)

# %%
new_dataset.intent.value_counts()
# Out:
# worker.terminate                              50
# workerTobaccoUsageStatus.update               50
# job.create                                    50
# worker.usI9Screening.section1.generate        50
# jobPosting.cancel                             50
# worker.usI9Screening.status.update            50
# location.update                               50
# jobFamily.deactivate                          50
# band.delete                                   50
# compensationPlan.create                       50
# jobReferral.hold                              50
# jobRequisitionRecruiter.assign                50
# data.import                                   50
# workerStudentStatus.update                    50
# adjustment                                    50
# personEthnicity.update                        50
# worker.changeManager                          50
# associateWageGarnishmentInstruction.create    50
# workAssignment.create                         50
# personDeathDate.inform                        50
# legalEntity.activate                          50
# workerSocialNetwork.update                    50
# personHeight.update                           50
# personGender.update                           50
# level.activate                                50
# associateGovernmentRegistration.create        50
# jobReferral.cancel                            50
# compensationPlanStep.create                   50
# jobSearch.delete                              50
# job.delete                                    50
#                                               ..
# workerBloodGroup.update                       50
# legalEntity.update                            50
# worker.changeLevel                            50
# assessment.submit                             50
# vendor.activate                               50
# helper.intents                                50
# candidate.refer                               50
# workerHeight.update                           50
# jobRequisition.hold                           50
# level.update                                  50
# evaluation.cancel                             50
# jobFamily.delete                              50
# legalEntity.create                            50
# workerBirthInformation.update                 50
# assessment.add                                50
# jobFamily.update                              50
# jobOffer.revoke                               50
# payGrade.deactivate                           50
# location.delete                               50
# transfer                                      50
# workerBusinessContactInformation.update       50
# payGrade.delete                               50
# personPersonalPhoneNumber.update              50
# jobRequisition.create                         50
# team.update                                   50
# jobReferral.evaluate                          50
# evaluation.update                             50
# personBloodGroup.update                       50
# band.activate                                 50
# position.deactivate                           50
# Name: intent, Length: 186, dtype: int64

# %%
new_dataset[new_dataset['intent']=='jobOffer.revoke']
# Out:
#                                                  phrase           intent
# 797                                   Pls rvk job offer  jobOffer.revoke
# 798               Please I want you to revoke job offer  jobOffer.revoke
# 799                 I need you to revoke this job offer  jobOffer.revoke
# 800                         Make a job offering revoked  jobOffer.revoke
# 801                    Help me to revoke a job offering  jobOffer.revoke
# 802                               Revoke this job offer  jobOffer.revoke
# 803                                Pls revoke job offer  jobOffer.revoke
# 804                           Let me revoke a job offer  jobOffer.revoke
# 805   Can you please help me to revoke this job offe...  jobOffer.revoke
# 806                                       Rvk job offer  jobOffer.revoke
# 807            Can you please let me revoke a job offer  jobOffer.revoke
# 808                     I need to revoke this job offer  jobOffer.revoke
# 809                                    Revoke job offer  jobOffer.revoke
# 810                      I want to withdraw a job offer  jobOffer.revoke
# 811                                  withdraw job offer  jobOffer.revoke
# 4828                                  Pls rvk job offer  jobOffer.revoke
# 4829  Can you please help me to revoke this job offe...  jobOffer.revoke
# 4830                              Revoke this job offer  jobOffer.revoke
# 4831                        Make a job offering revoked  jobOffer.revoke
# 4832                    I need to revoke this job offer  jobOffer.revoke
# 4833  Can you please help me to revoke this job offe...  jobOffer.revoke
# 4834           Can you please let me revoke a job offer  jobOffer.revoke
# 4835                   Help me to revoke a job offering  jobOffer.revoke
# 4836                                 withdraw job offer  jobOffer.revoke
# 4837                   Help me to revoke a job offering  jobOffer.revoke
# 4838                    I need to revoke this job offer  jobOffer.revoke
# 4839                   Help me to revoke a job offering  jobOffer.revoke
# 4840                                  Pls rvk job offer  jobOffer.revoke
# 4841                                  Pls rvk job offer  jobOffer.revoke
# 4842                          Let me revoke a job offer  jobOffer.revoke
# 4843                    I need to revoke this job offer  jobOffer.revoke
# 4844                          Let me revoke a job offer  jobOffer.revoke
# 4845                    I need to revoke this job offer  jobOffer.revoke
# 4846                                 withdraw job offer  jobOffer.revoke
# 4847                                 withdraw job offer  jobOffer.revoke
# 4848                              Revoke this job offer  jobOffer.revoke
# 4849                    I need to revoke this job offer  jobOffer.revoke
# 4850           Can you please let me revoke a job offer  jobOffer.revoke
# 4851                                   Revoke job offer  jobOffer.revoke
# 4852                        Make a job offering revoked  jobOffer.revoke
# 4853              Please I want you to revoke job offer  jobOffer.revoke
# 4854                     I want to withdraw a job offer  jobOffer.revoke
# 4855              Please I want you to revoke job offer  jobOffer.revoke
# 4856  Can you please help me to revoke this job offe...  jobOffer.revoke
# 4857                                 withdraw job offer  jobOffer.revoke
# 4858                   Help me to revoke a job offering  jobOffer.revoke
# 4859                        Make a job offering revoked  jobOffer.revoke
# 4860                                      Rvk job offer  jobOffer.revoke
# 4861                                   Revoke job offer  jobOffer.revoke
# 4862                                  Pls rvk job offer  jobOffer.revoke
